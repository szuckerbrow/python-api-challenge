# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pprint import pprint

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        0   kapuskasing  49.4169 -82.4331    -20.95        77          20
# 1        1          kirs  59.3388  52.2447    -10.32        95         100
# 2        2  san patricio  28.0170 -97.5169     13.92        53         100
# 3        3         pskov  57.8136  28.3496     -9.05        92         100
# 4        4         pisco -13.7000 -76.2167     21.12        83         100
#
#    Wind Speed Country                     Date
# 0        2.06      CA  2023-12-04 13:49:10 UTC
# 1        3.34      RU  2023-12-04 13:49:10 UTC
# 2        3.14      US  2023-12-04 13:49:10 UTC
# 3        0.00      RU  2023-12-04 13:49:10 UTC
# 4        3.09      PE  2023-12-04 13:49:10 UTC

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 600,
    frame_height = 400,
    size = "Humidity",
    scale = 0.4,
    color = "City",
    alpha = 0.5
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_narrowed_df = city_data_df[(city_data_df["Max Temp"]<27) & (city_data_df["Max Temp"]>21)
                                    & (city_data_df["Wind Speed"]<4.5) & (city_data_df["Cloudiness"]==0)]

# Drop any rows with null values
city_data_narrowed_df = city_data_narrowed_df.dropna()

# Display sample data
city_data_narrowed_df.head()
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 97        97       vallenar -28.5708  -70.7581     22.82        44
# 219      219    tamanrasset  22.7850    5.5228     24.95         9
# 261      261  alice springs -23.7000  133.8833     23.75        43
# 354      354     as samawah  31.3320   45.2944     22.08        27
# 370      370          la'ie  21.6477 -157.9253     23.95        82
#
#      Cloudiness  Wind Speed Country                     Date
# 97            0        2.71      CL  2023-12-04 13:49:23 UTC
# 219           0        3.09      DZ  2023-12-04 13:49:38 UTC
# 261           0        2.57      AU  2023-12-04 13:49:41 UTC
# 354           0        3.28      IQ  2023-12-04 13:49:47 UTC
# 370           0        2.24      US  2023-12-04 13:49:48 UTC

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# Had to loook up the difference between shallow and deep copy
# Decided to use a deep copy so the new df will be independent and not affect the first df
hotel_df = city_data_narrowed_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy(deep=True)  # Deep copy

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#               City Country      Lat       Lng  Humidity Hotel Name
# 97        vallenar      CL -28.5708  -70.7581        44
# 219    tamanrasset      DZ  22.7850    5.5228         9
# 261  alice springs      AU -23.7000  133.8833        43
# 354     as samawah      IQ  31.3320   45.2944        27
# 370          la'ie      US  21.6477 -157.9253        82

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "apiKey":geoapify_key,
    "categories":"accommodation.hotel"
#     "format":"json"
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index, "Lat"]
    longitude = hotel_df.loc[index, "Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    city = row["City"] + "," + row["Country"]
    params["text"] = f"{city}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# vallenar - nearest hotel: Hotel del Marqués
# tamanrasset - nearest hotel: فندق الأمان
# alice springs - nearest hotel: Aurora Alice Springs
# as samawah - nearest hotel: فندق قصر الغدير
# la'ie - nearest hotel: No hotel found
# holualoa - nearest hotel: Kona Hotel
# champerico - nearest hotel: Hotel y Restaurante El Submarino
# hafar al-batin - nearest hotel: فندق الفرحان
# tannum sands - nearest hotel: No hotel found
# ghat - nearest hotel: فندق تاسيلي
#                City Country      Lat       Lng  Humidity  \
# 97         vallenar      CL -28.5708  -70.7581        44
# 219     tamanrasset      DZ  22.7850    5.5228         9
# 261   alice springs      AU -23.7000  133.8833        43
# 354      as samawah      IQ  31.3320   45.2944        27
# 370           la'ie      US  21.6477 -157.9253        82
# 412        holualoa      US  19.6228 -155.9522        82
# 418      champerico      GT  14.3000  -91.9167        76
# ...

# %%
# # this kernel is being used to play around with just one city because my above for loop was not working properly

# latitude = -28.5708
# longitude = -70.7581

# radius = 10000
# params = {
#     "apiKey":geoapify_key,
#     "categories":"accommodation.hotel",
#     "filter":f"circle:{longitude},{latitude},{radius}",
#     "bias":f"proximity:{longitude},{latitude}"
# }

# base_url = "https://api.geoapify.com/v2/places"
# name_address = requests.get(base_url, params=params).json()
# pprint(name_address)

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.8,
    color = "City",
    alpha = 0.5,
    hover_cols=["Lng", "Lat", "City", "Humidity", "Hotel Name", "Country"]
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
