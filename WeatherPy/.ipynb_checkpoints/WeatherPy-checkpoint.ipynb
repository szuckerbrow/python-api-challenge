# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 585

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# test kernel to API call for just one city and go from there
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&units&q="

test_city = requests.get(query_url + "jamestown").json()
# pprint(test_city)

test_lat = test_city["coord"]["lat"]
test_lng = test_city["coord"]["lon"]
test_max_temp = test_city["main"]["temp_max"]
test_max_temp = test_max_temp - 273.15
test_humidity = test_city["main"]["humidity"]
test_clouds = test_city["clouds"]["all"]
test_wind = test_city["wind"]["speed"]
test_country = test_city["sys"]["country"]
test_date = test_city["dt"]

test_date_formatted = datetime.utcfromtimestamp(test_date).strftime('%Y-%m-%d %H:%M:%S UTC')

print(f"{test_lat} \n{test_lng} \n{test_max_temp} \n{test_humidity} \n{test_clouds} \n{test_wind} \n{test_country} \n{test_date_formatted}")
# Out:
# 42.097
# -79.2353
# 13.340000000000032
# 79
# 100
# 4.02
# US
# 2023-12-03 18:23:38 UTC

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&units&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
# this will give a number to each city in the list of cities. Ex - Index 0, city name
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    # i % 50 == 0 is looking to see if i is divisible by 50 with no remainder
    # once it finds an i value where this is true, i.e. 50, then it will add 1 to the set count and reset the record_count to 0
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = query_url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_max_temp = city_max_temp - 273.15
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"] #figured out later to add ["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        city_date = datetime.utcfromtimestamp(city_date).strftime('%Y-%m-%d %H:%M:%S UTC')

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | boa vista
# Processing Record 2 of Set 1 | lisakovsk
# Processing Record 3 of Set 1 | edinburgh of the seven seas
# Processing Record 4 of Set 1 | blackmans bay
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | iqaluit
# Processing Record 7 of Set 1 | devonport
# Processing Record 8 of Set 1 | port-gentil
# Processing Record 9 of Set 1 | talnakh
# Processing Record 10 of Set 1 | ust-nera
# Processing Record 11 of Set 1 | yanbu
# Processing Record 12 of Set 1 | akureyri
# Processing Record 13 of Set 1 | college
# Processing Record 14 of Set 1 | al jawf
# Processing Record 15 of Set 1 | sofo-birnin-gwari
# Processing Record 16 of Set 1 | margate
# Processing Record 17 of Set 1 | port-aux-francais
# Processing Record 18 of Set 1 | grytviken
# Processing Record 19 of Set 1 | ulladulla
# Processing Record 20 of Set 1 | adamstown
# Processing Record 21 of Set 1 | anadyr
# Processing Record 22 of Set 1 | hadibu
# Processing Record 23 of Set 1 | mbuji-mayi
# Processing Record 24 of Set 1 | tezu
# Processing Record 25 of Set 1 | stanley
# Processing Record 26 of Set 1 | whitehorse
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | balkanabat
# Processing Record 29 of Set 1 | vila velha
# Processing Record 30 of Set 1 | le port
# Processing Record 31 of Set 1 | coxim
# Processing Record 32 of Set 1 | mejit
# Processing Record 33 of Set 1 | rio grande
# Processing Record 34 of Set 1 | port mathurin
# Processing Record 35 of Set 1 | qaqortoq
# Processing Record 36 of Set 1 | petropavlovsk-kamchatsky
# Processing Record
# Processing Record 25 of Set 4 | sorong
# Processing Record 26 of Set 4 | okha
# Processing Record 27 of Set 4 | laayoune plage
# City not found. Skipping...
# Processing Record 28 of Set 4 | rongelap
# Processing Record 29 of Set 4 | tanrake village
# City not found. Skipping...
# Processing Record 30 of Set 4 | saipan
# Processing Record 31 of Set 4 | alamos
# Processing Record 32 of Set 4 | rasra
# Processing Record 33 of Set 4 | enewetak
# Processing Record 34 of Set 4 | hamilton
# Processing Record 35 of Set 4 | otegen batyra
# Processing Record 36 of Set 4 | atafu village
# Processing Record 37 of Set 4 | yemetsk
# Processing Record 38 of Set 4 | broome
# Processing Record 39 of Set 4 | cockburn town
# Processing Record 40 of Set 4 | papao
# Processing Record 41 of Set 4 | fortuna
# Processing Record 42 of Set 4 | ariguani
# Processing Record 43 of Set 4 | odda
# Processing Record 44 of Set 4 | robinson
# Processing Record 45 of Set 4 | susuman
# Processing Record 46 of Set 4 | goz beida
# Processing Record 47 of Set 4 | manchester
# Processing Record 48 of Set 4 | la jolla
# Processing Record 49 of Set 4 | tura
# Processing Record 0 of Set 5 | mitsamiouli
# Processing Record 1 of Set 5 | wailua homesteads
# Processing Record 2 of Set 5 | saynshand
# Processing Record 3 of Set 5 | vadso
# Processing Record 4 of Set 5 | botshabelo
# Processing Record 5 of Set 5 | nar'yan-mar
# Processing Record 6 of Set 5 | tuban
# Processing Record 7 of Set 5 | fale old settlement
# Processing Record 8 of Set 5 | qarazhal
# Processing Record 9 of Set 5 | zaghouan
# Processing Record 10 of Set 5 | kavieng
# Processing Record 11 of Set 5 | sarandi del yi
# Processing Record 12 of Set 5 | carnarvon
# Processing Record 13 of Set 5 | sierra grande
# Processing Record 14 of Set 5 | dzhambeyty
# Processing Record 15 of Set 5 | guatire
# Processing Record 16 of Set 5 | san patricio
# Processing Record 17 of Set 5 | ataq
# Processing Record 18 of Set 5 | schrobenhausen
# Processing Record 19 of Set 5 | kupang
# Processing Record 20 of Set 5 | augusto correa
# Processing Record 21 of Set 5 | sandnessjoen
# Processing Record 22 of Set 5 | nichinan
# Processing Record 23 of Set 5 | laguna de perlas
# Processing Record 24 of Set 5 | tamanrasset
# Processing Record 25 of Set 5 | weno
# Processing Record 26 of Set 5 | puerto ayora
# Processing Record 27 of Set 5 | melfi
# Processing Record 28 of Set 5 | al hufuf
# Processing Record 29 of Set 5 | revda
# Processing Record 30 of Set 5 | lebu
# Processing Record 31 of Set 5 | arraial do cabo
# Processing Record 32 of Set 5 | puerto baquerizo moreno
# Processing Record 33 of Set 5 | chonchi
# Processing Record 34 of Set 5 | kavaratti
# Processing Record 35 of Set 5 | kourou
# Processing Record 36 of Set 5 | shahrinav
# Processing Record 37 of Set 5 | sitka
# Processing Record 38 of Set 5 | trujillo
# Processing Record 39 of Set 5 | bayanhongor
# Processing Record 40 of Set 5 | greenwood
# Processing Record 41 of Set 5 | badger
# Processing Record 42 of Set 5 | egilsstadir
# Processing Record 43 of Set 5 | kristiansund
# Processing Record 44 of Set 5 | amahai
# Processing Record 45 of Set 5 | mudgee
# Processing Record 46 of Set 5 | murzuq
# Processing Record 47 of Set 5 | maluso
# Processing Record 48 of Set 5 | kiunga
# Processing Record 49 of Set 5 | beloyarskiy
# Processing Record 0 of Set 6 | touros
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | mossel bay
# Processing Record 3 of Set 6 | plouzane
# Processing Record 4 of Set 6 | muli
# Processing Record 5 of Set 6 | svyetlahorsk
# Processing Record 6 of Set 6 | macusani
# Processing Record 7 of Set 6 | argostolion
# Processing Record 8 of Set 6 | port sudan
# Processing Record 9 of Set 6 | kayangel
# Processing Record 10 of Set 6 | kolondieba
# Processing Record 11 of Set 6 | muzaffarabad
# Processing Record 12 of Set 6 | la ronge
# Processing Record 13 of Set 6 | chiras
# Processing Record 14 of Set 6 | santa ana
# Processing Record 15 of Set 6 | utrik
# Processing Record 16 of Set 6 | sitangkai
# Processing Record 17 of Set 6 | xichang
# Processing Record 18 of Set 6 | pemangkat
# Processing Record 19 of Set 6 | cozumel
# Processing Record 20 of Set 6 | abraham's bay
# City not found. Skipping...
# Processing Record 21 of Set 6 | sosnovka
# Processing Record 22 of Set 6 | mount pearl
# Processing Record 23 of Set 6 | ambodifotatra
# Processing Record 24 of Set 6 | quellon
# Processing Record 25 of Set 6 | vic
# Processing Record 26 of Set 6 | the pas
# Processing Record 27 of Set 6 | altai
# Processing Record 28 of Set 6 | dubbo
# Processing Record 29 of Set 6 | bhadrachalam
# Processing Record 30 of Set 6 | sao jose da coroa grande
# Processing Record 31 of Set 6 | kyakhta
# Processing Record 32 of Set 6 | darwin
# Processing Record 33 of Set 6 | vrangel'
# Processing Record 34 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 35 of Set 6 | miranda do douro
# Processing Record 36 of Set 6 | bergheim
# Processing Record 37 of Set 6 | toliara
# Processing Record 38 of Set 6 | afaahiti
# Processing Record 39 of Set 6 | brokopondo
# Processing Record 40 of Set 6 | mokhsogollokh
# Processing Record 41 of Set 6 | punta arenas
# Processing Record 42 of Set 6 | kaliua
# Processing Record 43 of Set 6 | mena
# Processing Record 44 of Set 6 | kuta
# Processing Record 45 of Set 6 | saint-joseph
# Processing Record 46 of Set 6 | ola
# Processing Record 47 of Set 6 | ad dilam
# Processing Record 48 of Set 6 | camabatela
# Processing Record 49 of Set 6 | shahrak
# Processing Record 0 of Set 7 | keflavik
# Processing Record 1 of Set 7 | flying fish cove
# Processing Record 2 of Set 7 | akjoujt
# Processing Record 3 of Set 7 | basse-terre
# Processing Record 4 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 5 of Set 7 | luganville
# Processing Record 6 of Set 7 | acarau
# Processing Record 7 of Set 7 | gaalkacyo
# Processing Record 8 of Set 7 | lerwick
# Processing Record 9 of Set 7 | popondetta
# Processing Record 10 of Set 7 | am djarass
# Processing Record 47 of Set 9 | tutoia
# Processing Record 48 of Set 9 | new norfolk
# Processing Record 49 of Set 9 | santa marta
# Processing Record 0 of Set 10 | okhotsk
# Processing Record 1 of Set 10 | mariehamn
# Processing Record 2 of Set 10 | makoua
# Processing Record 3 of Set 10 | juneau
# Processing Record 4 of Set 10 | island harbour
# Processing Record 5 of Set 10 | onega
# Processing Record 6 of Set 10 | kulhudhuffushi
# Processing Record 7 of Set 10 | winnemucca
# Processing Record 8 of Set 10 | aqadyr
# Processing Record 9 of Set 10 | artvin
# Processing Record 10 of Set 10 | nova sintra
# Processing Record 11 of Set 10 | villa gesell
# Processing Record 12 of Set 10 | borzya
# Processing Record 13 of Set 10 | governador valadares
# Processing Record 14 of Set 10 | kilindoni
# Processing Record 15 of Set 10 | akrehamn
# Processing Record 16 of Set 10 | kirakira
# Processing Record 17 of Set 10 | kirsanov
# Processing Record 18 of Set 10 | cannonvale
# Processing Record 19 of Set 10 | kapa'a
# Processing Record 20 of Set 10 | praia da vitoria
# Processing Record 21 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 22 of Set 10 | west bay
# Processing Record 23 of Set 10 | mingguang
# Processing Record 24 of Set 10 | constitucion
# Processing Record 25 of Set 10 | staryye ozinki
# Processing Record 26 of Set 10 | ak-suu
# Processing Record 27 of Set 10 | xuchang
# Processing Record 28 of Set 10 | kilju
# Processing Record 29 of Set 10 | bonthe
# Processing Record 30 of Set 10 | pandan
# Processing Record 31 of Set 10 | saint-francois
# Processing Record 32 of Set 10 | colchani
# Processing Record 33 of Set 10 | fisterra
# Processing Record 34 of Set 10 | voss
# Processing Record 35 of Set 10 | rudbar
# Processing Record 36 of Set 10 | necochea
# Processing Record 37 of Set 10 | port moresby
# Processing Record 38 of Set 10 | benevides
# Processing Record 39 of Set 10 | hasaki
# Processing Record 40 of Set 10 | morondava
# Processing Record 41 of Set 10 | mpraeso
# Processing Record 42 of Set 10 | praya
# Processing Record 43 of Set 10 | verkhneye kazanishche
# Processing Record 44 of Set 10 | floro
# Processing Record 45 of Set 10 | dzerzhinskoye
# Processing Record 46 of Set 10 | dazhou
# Processing Record 47 of Set 10 | mahina
# Processing Record 48 of Set 10 | selkirk
# Processing Record 49 of Set 10 | meadow lakes
# Processing Record 0 of Set 11 | lae
# Processing Record 1 of Set 11 | novyy urgal
# Processing Record 2 of Set 11 | wasilkow
# Processing Record 3 of Set 11 | forbes
# Processing Record 4 of Set 11 | charters towers
# Processing Record 5 of Set 11 | lata
# Processing Record 6 of Set 11 | siwa oasis
# Processing Record 7 of Set 11 | porto novo
# Processing Record 8 of Set 11 | chul'man
# Processing Record 9 of Set 11 | mumford
# Processing Record 10 of Set 11 | mata-utu
# Processing Record 11 of Set 11 | kharan
# Processing Record 12 of Set 11 | happy valley-goose bay
# Processing Record 13 of Set 11 | lefka
# Processing Record 14 of Set 11 | bonnyville
# Processing Record 15 of Set 11 | mount isa
# Processing Record 16 of Set 11 | nova vicosa
# Processing Record 17 of Set 11 | arkhangel'sk
# Processing Record 18 of Set 11 | horqueta
# Processing Record 19 of Set 11 | colonia
# Processing Record 20 of Set 11 | newman
# Processing Record 21 of Set 11 | turpan
# Processing Record 22 of Set 11 | kievka
# Processing Record 23 of Set 11 | ust-tsilma
# Processing Record 24 of Set 11 | ta`u
# Processing Record 25 of Set 11 | luuq
# Processing Record 26 of Set 11 | yangor
# City not found. Skipping...
# Processing Record 27 of Set 11 | ponta delgada
# Processing Record 28 of Set 11 | pimentel
# Processing Record 29 of Set 11 | al muwayh
# Processing Record 30 of Set 11 | bokajan
# Processing Record 31 of Set 11 | reggane
# Processing Record 32 of Set 11 | manokwari
# Processing Record 33 of Set 11 | ugoofaaru
# Processing Record 34 of Set 11 | bandarbeyla
# Processing Record 35 of Set 11 | tadine
# Processing Record 36 of Set 11 | rabigh
# Processing Record 37 of Set 11 | aitape
# Processing Record 38 of Set 11 | we
# City not found. Skipping...
# Processing Record 39 of Set 11 | benguela
# Processing Record 40 of Set 11 | quincy
# Processing Record 41 of Set 11 | kem'
# Processing Record 42 of Set 11 | greenville
# Processing Record 43 of Set 11 | big bend
# Processing Record 44 of Set 11 | buta
# Processing Record 45 of Set 11 | muchkapskiy
# Processing Record 46 of Set 11 | mtambile
# Processing Record 47 of Set 11 | boguchany
# Processing Record 48 of Set 11 | portland
# Processing Record 49 of Set 11 | morehead city
# Processing Record 0 of Set 12 | piti village
# Processing Record 1 of Set 12 | pambujan
# Processing Record 2 of Set 12 | calliope
# Processing Record 3 of Set 12 | klamath falls
# Processing Record 4 of Set 12 | tofol
# Processing Record 5 of Set 12 | olavarria
# Processing Record 6 of Set 12 | north platte
# Processing Record 7 of Set 12 | oxelosund
# Processing Record 8 of Set 12 | altay
# Processing Record 9 of Set 12 | san antonio de pale
# Processing Record 10 of Set 12 | san agustin de valle fertil
# Processing Record 11 of Set 12 | sanandaj
# Processing Record 12 of Set 12 | nuku'alofa
# Processing Record 13 of Set 12 | kaspiyskiy
# Processing Record 14 of Set 12 | jijiga
# Processing Record 15 of Set 12 | figuig (centre)
# Processing Record 16 of Set 12 | longjiang
# Processing Record 17 of Set 12 | puerto colombia
# Processing Record 18 of Set 12 | fuglafjordur
# Processing Record 19 of Set 12 | horsham
# Processing Record 20 of Set 12 | george town
# Processing Record 21 of Set 12 | chunian
# Processing Record 22 of Set 12 | castillos
# Processing Record 23 of Set 12 | paracatu
# Processing Record 24 of Set 12 | muynoq
# Processing Record 25 of Set 12 | garoua boulai
# Processing Record 26 of Set 12 | al jadid
# Processing Record 27 of Set 12 | camargo
# Processing Record 28 of Set 12 | luau
# Processing Record 29 of Set 12 | centralia
# Processing Record 30 of Set 12 | aldama
# Processing Record 31 of Set 12 | mocorito
# Processing Record 32 of Set 12 | el calafate
# Processing Record 33 of Set 12 | coquimbo
# Processing Record 34 of Set 12 | dryden
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
print(city_data_df.count())
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# Country       564
# Date          564
# dtype: int64

# %%
# city_data_df["Max Temp"] = city_data_df["Max Temp"] - 273.15
# city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          boa vista   2.8197  -60.6733     33.99        40
# 1                          lisakovsk  52.5369   62.4936     -5.68        76
# 2        edinburgh of the seven seas -37.0676  -12.3116     15.42        73
# 3                      blackmans bay -43.0167  147.3167     11.96        93
# 4                             bethel  41.3712  -73.4140      8.53        89
#
#          Cloudiness  Wind Speed Country                     Date
# City_ID
# 0                40        7.20      BR  2023-12-03 18:26:40 UTC
# 1                 9        3.65      KZ  2023-12-03 18:29:16 UTC
# 2                 3        2.92      SH  2023-12-03 18:25:22 UTC
# 3                54        0.45      AU  2023-12-03 18:25:14 UTC
# 4               100        4.63      US  2023-12-03 18:21:04 UTC

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
scatter_x = city_data_df["Lat"]
scatter_y = city_data_df["Max Temp"]
plt.scatter(scatter_x, scatter_y, marker='o', edgecolors='black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Latitude vs Max Temperature (2023 - 12 - 03)")
plt.xlim(-60, 90)  # Set the x-axis limits
plt.ylim(-50, 40)  # Set the y-axis limits
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. temperature
scatter_x2 = city_data_df["Lat"]
scatter_y2 = city_data_df["Humidity"]
plt.scatter(scatter_x2, scatter_y2, marker='o', edgecolors='black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity (2023 - 12 - 03)")
plt.xlim(-60, 90)  # Set the x-axis limits
plt.ylim(0, 105)  # Set the y-axis limits
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# # Found this on google
# # Extract the numerical value from the 'Cloudiness' column
# city_data_df['Cloudiness'] = city_data_df['Cloudiness'].apply(lambda x: x['all'] if isinstance(x, dict) and 'all' in x else x)
# # Convert Cloudiness to numeric, handle non-numeric values gracefully
# city_data_df['Cloudiness'] = pd.to_numeric(city_data_df['Cloudiness'], errors='coerce')
# # Drop rows with NaN values in the 'Cloudiness' column
# city_data_df = city_data_df.dropna(subset=['Cloudiness'])

# Scatter plot was coming out very weird so this kernel is trying to figure that out

print(city_data_df[['Lat', 'Cloudiness']])
print(city_data_df['Cloudiness'].isna().sum())
print(city_data_df.dtypes)

# %%
# Build scatter plot for latitude vs. temperature
scatter_x3 = city_data_df["Lat"]
scatter_y3 = city_data_df["Cloudiness"]
plt.scatter(scatter_x3, scatter_y3, marker='o', edgecolors='black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title("City Latitude vs Cloudiness (2023 - 12 - 03)")
plt.xlim(-60, 90)  # Set the x-axis limits
plt.ylim(0, 105)  # Set the y-axis limits
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. temperature
scatter_x4 = city_data_df["Lat"]
scatter_y4 = city_data_df["Wind Speed"]
plt.scatter(scatter_x4, scatter_y4, marker='o', edgecolors='black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Latitude vs Wind Speed (2023 - 12 - 03)")
plt.xlim(-60, 90)  # Set the x-axis limits
plt.ylim(0, 15)  # Set the y-axis limits
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
